# %% [markdown]
# # Hourly historical weather data for all Saudi Arabia (EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn import datasets

# %%
df=pd.read_csv('weather-sa-2017-2019-clean.csv')
df.head()
# Out:
#    index  region      date  time  year  month  day  hour  minute weather  \
# 0      0  Qassim  1-Jan-17  0:00  2017      1    1    24       0  Clear
# 1      1  Qassim  1-Jan-17  1:00  2017      1    1     1       0  Clear
# 2      2  Qassim  1-Jan-17  3:00  2017      1    1     3       0  Clear
# 3      3  Qassim  1-Jan-17  4:00  2017      1    1     4       0  Clear
# 4      4  Qassim  1-Jan-17  5:00  2017      1    1     5       0  Clear
#
#    temp  wind humidity  barometer  visibility
# 0    17    11      64%     1018.0          16
# 1    17     6      64%     1018.0          16
# 2    15    11      72%     1019.0          16
# 3    15    11      72%     1019.0          16
# 4    15     9      72%     1019.0          16

# %%
df=df.sort_values('region')
df
# Out:
#          index region       date   time  year  month  day  hour  minute  \
# 135313  135313  Assir   1-Jan-17   0:00  2017      1    1    24       0
# 144299  144299  Assir  20-Oct-18  18:00  2018     10   20    18       0
# 144300  144300  Assir  20-Oct-18  19:00  2018     10   20    19       0
# 144301  144301  Assir  20-Oct-18  20:00  2018     10   20    20       0
# 144302  144302  Assir  20-Oct-18  21:00  2018     10   20    21       0
# ...        ...    ...        ...    ...   ...    ...  ...   ...     ...
# 121816  121816  Tabuk  10-Oct-17  13:00  2017     10   10    13       0
# 121815  121815  Tabuk  10-Oct-17  12:00  2017     10   10    12       0
# 121814  121814  Tabuk  10-Oct-17  11:00  2017     10   10    11       0
# 121821  121821  Tabuk  10-Oct-17  18:00  2017     10   10    18       0
# 124511  124511  Tabuk   1-Feb-18   2:00  2018      2    1     2       0
#
#                 weather  temp  wind humidity  barometer  visibility
# 135313           Clear     12     7     100%     1026.0          16
# 144299  Passing clouds     17     0      83%     1025.0          -1
# 144300  Passing clouds     17     0      83%     1025.0          -1
# 144301  Passing clouds     17     9      73%     1026.0          -1
# 144302  Passing clouds     17     7      83%     1027.0          -1
# ...                 ...   ...   ...      ...        ...         ...
# 121816           Sunny     27    13      34%     1016.0          16
# 121815           Sunny     26    11      42%     1017.0          16
# 121814           Sunny     25    11      44%     1017.0          16
# 121821           Sunny     28    19      28%     1014.0          16
# 124511           Clear      7     0      34%     1021.0          16
#
# [249023 rows x 15 columns]

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249023 entries, 135313 to 124511
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   index       249023 non-null  int64
#  1   region      249023 non-null  object
#  2   date        249023 non-null  object
#  3   time        249023 non-null  object
#  4   year        249023 non-null  int64
#  5   month       249023 non-null  int64
#  6   day         249023 non-null  int64
#  7   hour        249023 non-null  int64
#  8   minute      249023 non-null  int64
#  9   weather     249023 non-null  object
#  10  temp        249023 non-null  int64
#  11  wind        249023 non-null  int64
#  12  humidity    249006 non-null  object
#  13  barometer   248951 non-null  float64
#  14  visibility  249023 non-null  int64
# dtypes: float64(1), int64(9), object(5)
# memory usage: 30.4+ MB

# %%
df.shape
# Out:
# (249023, 15)

# %%
df['date'] = pd.to_datetime(df.date)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249023 entries, 135313 to 124511
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   index       249023 non-null  int64
#  1   region      249023 non-null  object
#  2   date        249023 non-null  datetime64[ns]
#  3   time        249023 non-null  object
#  4   year        249023 non-null  int64
#  5   month       249023 non-null  int64
#  6   day         249023 non-null  int64
#  7   hour        249023 non-null  int64
#  8   minute      249023 non-null  int64
#  9   weather     249023 non-null  object
#  10  temp        249023 non-null  int64
#  11  wind        249023 non-null  int64
#  12  humidity    249006 non-null  object
#  13  barometer   248951 non-null  float64
#  14  visibility  249023 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(9), object(4)
# memory usage: 30.4+ MB

# %%
df.describe()
# Out:
#                index           year          month            day  \
# count  249023.000000  249023.000000  249023.000000  249023.000000
# mean   121690.686174    2017.710007       6.050694      15.691081
# std     71831.546649       0.706113       3.521591       8.787958
# min         0.000000    2017.000000       1.000000       1.000000
# 25%     59402.500000    2017.000000       3.000000       8.000000
# 50%    121658.000000    2018.000000       6.000000      16.000000
# 75%    183913.500000    2018.000000       9.000000      23.000000
# max    246169.000000    2019.000000      12.000000      31.000000
#
#                 hour         minute           temp           wind  \
# count  249023.000000  249023.000000  249023.000000  249023.000000
# mean       12.536890       0.131108      24.722624      12.957104
# std         6.910254       1.970710       8.880913       8.711619
# min         1.000000       0.000000      -4.000000      -1.000000
# 25%         7.000000       0.000000      18.000000       7.000000
# 50%        13.000000       0.000000      24.000000      11.000000
# 75%        19.000000       0.000000      31.000000      19.000000
# max        24.000000      59.000000      50.000000     163.000000
#
#            barometer     visibility
# count  248951.000000  249023.000000
# mean     1015.455355      11.053453
# std         6.970779       7.053005
# min       904.000000      -1.000000
# 25%      1011.000000       5.000000
# 50%      1016.000000      16.000000
# 75%      1021.000000      16.000000
# max      1101.000000     161.000000

# %%
df['humidity'] = df['humidity'].str.rstrip('%').astype('float') 
df.head()
# Out:
#          index region       date   time  year  month  day  hour  minute  \
# 135313  135313  Assir 2017-01-01   0:00  2017      1    1    24       0
# 144299  144299  Assir 2018-10-20  18:00  2018     10   20    18       0
# 144300  144300  Assir 2018-10-20  19:00  2018     10   20    19       0
# 144301  144301  Assir 2018-10-20  20:00  2018     10   20    20       0
# 144302  144302  Assir 2018-10-20  21:00  2018     10   20    21       0
#
#                 weather  temp  wind  humidity  barometer  visibility
# 135313           Clear     12     7     100.0     1026.0          16
# 144299  Passing clouds     17     0      83.0     1025.0          -1
# 144300  Passing clouds     17     0      83.0     1025.0          -1
# 144301  Passing clouds     17     9      73.0     1026.0          -1
# 144302  Passing clouds     17     7      83.0     1027.0          -1

# %%
def get_sunny(weather):
    if 'Sunny'  in weather:
        return 100
    return 0
df['sunny'] = df.weather.map(get_sunny)

# %%
to_drop = ['index','barometer','visibility','minute','weather']
df.drop(to_drop, inplace=True, axis=1)
df.head()
# Out:
#        region       date   time  year  month  day  hour  temp  wind  humidity  \
# 135313  Assir 2017-01-01   0:00  2017      1    1    24    12     7     100.0
# 144299  Assir 2018-10-20  18:00  2018     10   20    18    17     0      83.0
# 144300  Assir 2018-10-20  19:00  2018     10   20    19    17     0      83.0
# 144301  Assir 2018-10-20  20:00  2018     10   20    20    17     9      73.0
# 144302  Assir 2018-10-20  21:00  2018     10   20    21    17     7      83.0
#
#         sunny
# 135313      0
# 144299      0
# 144300      0
# 144301      0
# 144302      0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [region, date, time, year, month, day, hour, temp, wind, humidity, sunny]
# Index: []

# %%
df.region.str.replace(',', '')
# Out:
# 135313    Assir
# 144299    Assir
# 144300    Assir
# 144301    Assir
# 144302    Assir
#           ...
# 121816    Tabuk
# 121815    Tabuk
# 121814    Tabuk
# 121821    Tabuk
# 124511    Tabuk
# Name: region, Length: 249023, dtype: object

# %%
df['region'].replace({'EP':'ER',"Jawf":"Aljawf"} ,inplace=True)
df.region = df.region.str.replace('Northern boarder','NB')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249023 entries, 135313 to 124511
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   region    249023 non-null  object
#  1   date      249023 non-null  datetime64[ns]
#  2   time      249023 non-null  object
#  3   year      249023 non-null  int64
#  4   month     249023 non-null  int64
#  5   day       249023 non-null  int64
#  6   hour      249023 non-null  int64
#  7   temp      249023 non-null  int64
#  8   wind      249023 non-null  int64
#  9   humidity  249006 non-null  float64
#  10  sunny     249023 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(2)
# memory usage: 22.8+ MB

# %%
df.isna().sum()
# Out:
# region       0
# date         0
# time         0
# year         0
# month        0
# day          0
# hour         0
# temp         0
# wind         0
# humidity    17
# sunny        0
# dtype: int64

# %%
df.describe()
# Out:
#                 year          month            day           hour  \
# count  249023.000000  249023.000000  249023.000000  249023.000000
# mean     2017.710007       6.050694      15.691081      12.536890
# std         0.706113       3.521591       8.787958       6.910254
# min      2017.000000       1.000000       1.000000       1.000000
# 25%      2017.000000       3.000000       8.000000       7.000000
# 50%      2018.000000       6.000000      16.000000      13.000000
# 75%      2018.000000       9.000000      23.000000      19.000000
# max      2019.000000      12.000000      31.000000      24.000000
#
#                 temp           wind       humidity          sunny
# count  249023.000000  249023.000000  249006.000000  249023.000000
# mean       24.722624      12.957104      37.553139      33.006590
# std         8.880913       8.711619      23.593068      47.023748
# min        -4.000000      -1.000000       0.000000       0.000000
# 25%        18.000000       7.000000      17.000000       0.000000
# 50%        24.000000      11.000000      32.000000       0.000000
# 75%        31.000000      19.000000      55.000000     100.000000
# max        50.000000     163.000000     100.000000     100.000000

# %%
df.wind[df.wind <0] = None;
# Out:
# <ipython-input-163-cc266ee70586>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wind[df.wind <0] = None;

# %%
df_box=df[['temp','wind','humidity']]
sns.boxplot(data=df_box)
sns.despine(offset=0, trim=True)

# %%
sns.boxplot(df['temp']);
# Out:
# C:\Users\WELCOME\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['wind']);
# Out:
# C:\Users\WELCOME\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.wind[df.wind >70]=None;
# Out:
# <ipython-input-167-55a074a8f235>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wind[df.wind >70]=None;

# %%
df.isna().sum()
# Out:
# region        0
# date          0
# time          0
# year          0
# month         0
# day           0
# hour          0
# temp          0
# wind        115
# humidity     17
# sunny         0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#        region       date   time  year  month  day  hour  temp  wind  humidity  \
# 147437  Assir 2019-03-03  14:00  2019      3    3    14    24   NaN      25.0
# 141864  Assir 2017-10-07  20:00  2017     10    7    20    23   NaN      19.0
# 139444  Assir 2017-06-26  19:00  2017      6   26    19    28   NaN      12.0
# 218588   Baha 2018-02-24   9:00  2018      2   24     9    20   NaN      56.0
# 214518   Baha 2017-09-04   7:00  2017      9    4     7    24   NaN      25.0
# ...       ...        ...    ...   ...    ...  ...   ...   ...   ...       ...
# 131821  Tabuk 2018-12-05   5:00  2018     12    5     5    12   NaN      58.0
# 124812  Tabuk 2018-02-13  14:00  2018      2   13    14    18  30.0       NaN
# 121096  Tabuk 2017-09-10  11:00  2017      9   10    11    35   NaN      25.0
# 120239  Tabuk 2017-08-05   8:00  2017      8    5     8    27   NaN      39.0
# 122248  Tabuk 2017-10-28  17:00  2017     10   28    17    30   NaN      20.0
#
#         sunny
# 147437    100
# 141864      0
# 139444      0
# 218588    100
# 214518    100
# ...       ...
# 131821      0
# 124812      0
# 121096      0
# 120239    100
# 122248      0
#
# [132 rows x 11 columns]

# %%
df=df.interpolate(method='linear')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249023 entries, 135313 to 124511
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   region    249023 non-null  object
#  1   date      249023 non-null  datetime64[ns]
#  2   time      249023 non-null  object
#  3   year      249023 non-null  int64
#  4   month     249023 non-null  int64
#  5   day       249023 non-null  int64
#  6   hour      249023 non-null  int64
#  7   temp      249023 non-null  int64
#  8   wind      249023 non-null  float64
#  9   humidity  249023 non-null  float64
#  10  sunny     249023 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(2)
# memory usage: 22.8+ MB

# %%
df.isna().sum()
# Out:
# region      0
# date        0
# time        0
# year        0
# month       0
# day         0
# hour        0
# temp        0
# wind        0
# humidity    0
# sunny       0
# dtype: int64

# %%
sns.boxplot(df['wind']);
# Out:
# C:\Users\WELCOME\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df1 = df.loc[(df.index) , ['region','sunny','wind','temp','humidity','day']]
avrg = df1.groupby(by = ['region']).mean()
#avrg.reset_index(level=0, inplace=True)
avrg
# Out:
#             sunny       wind       temp   humidity        day
# region
# Aljawf  37.278892  13.853331  23.101268  30.499926  15.681456
# Assir   26.972123  12.350942  20.257414  47.590154  15.708185
# Baha    27.852097  14.591037  23.468110  38.722982  15.685355
# ER      36.595515  14.850554  27.215077  45.095488  15.714888
# Hail    34.491327  12.876696  25.927837  41.532826  15.680831
# Jazan   26.733572  12.374704  20.711735  45.803066  15.681426
# Madina  37.700977  11.793038  28.708740  19.971600  15.684798
# Mecca   32.188672  13.909883  29.023239  54.158772  15.681419
# NB      40.004942  13.601285  24.978799  26.264344  15.694490
# Najran  26.754673  12.393888  20.692951  45.953645  15.673099
# Qassim  34.628404  12.863967  25.961350  41.476204  15.546304
# Riyadh  30.899458  10.570915  27.957981  24.087936  15.910298
# Tabuk   34.649209  11.951408  22.638735  28.718355  15.686709

# %%
df2 = df.loc[(df['year'] == 2017) , ['region','sunny','temp','humidity','wind','day','month','year']]
avrg_M17 = df2.groupby(by = ['region','month']).mean()
avrg_M17.reset_index(level=0,inplace=True)
avrg_M17
# Out:
#        region      sunny       temp   humidity       wind        day    year
# month
# 1      Aljawf  29.019074  10.538147  42.277929  12.633515  16.038147  2017.0
# 2      Aljawf  37.462687  10.435821  27.670896  14.570149  14.482090  2017.0
# 3      Aljawf  34.214003  17.721268  37.919419  18.578600  15.826948  2017.0
# 4      Aljawf  32.653061  23.209524  25.767347  16.746939  15.538776  2017.0
# 5      Aljawf  49.597855  29.463807  15.453083  15.614611  15.957105  2017.0
# ...       ...        ...        ...        ...        ...        ...     ...
# 8       Tabuk  37.313433  34.401628  19.185889  12.442334  15.925373  2017.0
# 9       Tabuk  34.685315  30.885315  21.503497  10.965734  15.525874  2017.0
# 10      Tabuk  46.081081  23.885135  28.681081   9.924324  15.989189  2017.0
# 11      Tabuk  28.531469  18.050350  40.110490   8.441958  15.495105  2017.0
# 12      Tabuk  31.707317  14.525745  37.146341   8.979675  16.134146  2017.0
#
# [154 rows x 7 columns]

# %%
df3 = df.loc[(df['year'] == 2018) , ['region','sunny','temp','humidity','wind','day','month','year']]
avrg_M18 = df3.groupby(by = ['region','month']).mean()
avrg_M18.reset_index(level=0,inplace=True)
avrg_M18
# Out:
#        region      sunny       temp   humidity       wind        day    year
# month
# 1      Aljawf  25.845737  10.880920  48.304465  14.472260  15.788904  2018.0
# 2      Aljawf  24.850299  15.976048  38.474551  14.230539  14.640719  2018.0
# 3      Aljawf  37.983425  22.069061  23.527624  14.812155  16.110497  2018.0
# 4      Aljawf  33.333333  23.266949  26.853107  16.573446  15.555085  2018.0
# 5      Aljawf  34.718499  28.683646  21.242627  17.757373  15.765416  2018.0
# ...       ...        ...        ...        ...        ...        ...     ...
# 8       Tabuk  51.282051  32.175439  22.993252  12.900135  16.006748  2018.0
# 9       Tabuk  27.538248  32.070932  20.866481  11.532684  15.546592  2018.0
# 10      Tabuk  29.704301  25.326613  31.458333  12.767473  16.045699  2018.0
# 11      Tabuk  12.656467  17.760779  49.553547  10.090403  15.532684  2018.0
# 12      Tabuk  25.864454  13.413555  47.991701   9.715076  15.793914  2018.0
#
# [145 rows x 7 columns]

# %%
df4 = df.loc[(df['year'] == 2019) , ['region','sunny','temp','humidity','wind','day','month','year']]
avrg_M19 = df4.groupby(by = ['region','month']).mean()
avrg_M19.reset_index(level=0,inplace=True)
avrg_M19
# Out:
#        region      sunny       temp   humidity       wind        day    year
# month
# 1      Aljawf  23.505976  11.759628  50.795485  13.475432  16.131474  2019.0
# 2      Aljawf  26.002972  12.939079  55.610698   9.644874  14.405646  2019.0
# 3      Aljawf  33.055556  15.548611  38.075000  15.838889  16.006944  2019.0
# 4      Aljawf  37.765205  20.625177  29.540311  12.766620  15.554455  2019.0
# 1       Assir  42.019100  17.125512  51.613915  10.922237  15.948158  2019.0
# 2       Assir  25.722983  17.484018  58.039574  15.611872  14.407915  2019.0
# 3       Assir  28.412256  18.732591  53.750696  19.901114  16.089136  2019.0
# 4       Assir  20.084866  21.107496  52.875530  15.360679  15.524752  2019.0
# 1        Baha  29.614325  18.687328  50.820937  12.545455  16.085399  2019.0
# 2        Baha  19.541985  18.236641  51.073282  13.781679  14.363359  2019.0
# 3        Baha  28.591160  19.390884  33.197514  17.258287  15.924033  2019.0
# 4        Baha  18.439716  23.293617  35.628369  15.578723  15.527660  2019.0
# 1          ER  27.641100  18.594790  56.222865  16.797395  16.185239  2019.0
# 2          ER  22.857143  18.184127  57.407937  16.444444  14.347619  2019.0
# 3          ER  32.262997  20.747706  49.250765  17.162080  16.025994  2019.0
# 4          ER  31.770045  25.819970  45.195915  16.996974  15.538578  2019.0
# 1        Hail  11.036339  15.666218  67.018843  12.106326  16.002692  2019.0
# 2        Hail  23.008850  15.356932  67.438053  13.283186  14.480826  2019.0
# 3        Hail  27.808219  18.813699  47.691781  14.516438  16.030137  2019.0
# 4        Hail  27.310924  23.371148  47.651261  14.141457  15.522409  2019.0
# 1       Jazan  41.975309  17.109739  50.882030  10.702332  15.902606  2019.0
# 2       Jazan  24.200913  17.449011  58.614916  15.267884  14.407915  2019.0
# 3       Jazan  28.412256  18.732591  53.750696  19.889276  16.089136  2019.0
# 4       Jazan  20.226308  21.097595  52.872702  15.315417  15.524752  2019.0
# 1      Madina  25.572005  20.555855  42.044415   9.590848  16.043069  2019.0
# 2      Madina  29.668675  20.165663  34.548193  12.144578  14.475904  2019.0
# 3      Madina  41.192412  22.264228  22.146341  13.042005  16.023035  2019.0
# 4      Madina  37.623762  27.345120  19.985856  12.434936  15.579915  2019.0
# 1       Mecca  16.869096  25.016194  60.962213  13.221323  16.035088  2019.0
# 2       Mecca  21.021021  24.900901  51.545045  15.477477  14.475976  2019.0
# 3       Mecca  27.272727  24.932157  50.404342  16.377205  16.032564  2019.0
# 4       Mecca  36.605891  27.778401  50.350631  15.070126  15.518934  2019.0
# 1          NB  26.005362  15.863271  40.036193  14.457105  16.049598  2019.0
# 2          NB  38.208955  17.817910  38.500000  11.945522  14.464179  2019.0
# 3          NB  40.055249  22.968232  22.401934  16.012431  16.129834  2019.0
# 4          NB  44.662921  26.102528  22.443820  15.179775  15.498596  2019.0
# 1      Najran  41.064120  17.075034  51.813097  10.897681  15.933151  2019.0
# 2      Najran  25.000000  17.446970  58.322727  15.124242  14.451515  2019.0
# 3      Najran  29.068150  18.664812  54.367177  19.974965  16.075104  2019.0
# 4      Najran  20.113314  20.958924  53.413598  15.839943  15.526912  2019.0
# 1      Qassim  11.036339  15.666218  67.018843  12.106326  16.002692  2019.0
# 2      Qassim  23.008850  15.356932  67.438053  13.283186  14.480826  2019.0
# 3      Qassim  27.808219  18.813699  47.691781  14.516438  16.030137  2019.0
# 4      Qassim  21.818182  23.376623  49.761039  13.901299   8.587013  2019.0
# 1      Riyadh  21.542553  17.194149  36.857713   9.779255  15.964096  2019.0
# 2      Riyadh  24.519941  17.187592  37.514032  11.220089  14.419498  2019.0
# 3      Riyadh  26.685007  20.016506  27.092160  12.947730  16.082531  2019.0
# 4      Riyadh  19.915849  24.946704  30.060309  12.172511  15.509116  2019.0
# 1       Tabuk  25.301205  12.527443  43.852744  11.235609  16.057564  2019.0
# 2       Tabuk  20.505201  13.915305  42.526003  12.662704  14.456166  2019.0
# 3       Tabuk  28.065395  16.163488  31.404632  13.768392  15.959128  2019.0
# 4       Tabuk  35.195531  20.955307  24.993017  13.231844  15.515363  2019.0

# %%
avrg['sunny'].nlargest(5)
# Out:
# region
# NB        40.004942
# Madina    37.700977
# Aljawf    37.278892
# ER        36.595515
# Tabuk     34.649209
# Name: sunny, dtype: float64

# %%
avrg['wind'].nlargest(5)
# Out:
# region
# ER        14.850554
# Baha      14.591037
# Mecca     13.909883
# Aljawf    13.853331
# NB        13.601285
# Name: wind, dtype: float64

# %%
# plt.figure(figsize=(12,18))
#df= df.sort_values("wind", ascending=True)
plt.title('Comparison of regions]',fontsize = 16)

fig, ax = plt.subplots(2, 2)
fig.set_size_inches(12, 14)
## sun = df.groupby("region").sunny()
# df[['region', 'sunny']].groupby(['region']).sort_values(by='sunny')
# sunny_sorted = np.sort(df.sunny.unique())
sns.barplot(data= df, y = df.region, x = df.sunny , ax =ax[0,0], color="orange")
sns.barplot(data= df, y = df.region, x = df.wind , ax =ax[0,1], color="gray")
sns.barplot(data= df, y = df.region, x = df.temp , ax =ax[1,0], color="blue")
sns.barplot(data= df, y = df.region, x = df.humidity , ax =ax[1,1], color="red")
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='region'>

# %%
plt.figure(figsize=[15,3])



plt.suptitle('Frequency of Wind Speed',fontsize = 16,y=1.1)


plt.subplot(1,3,1)
plt.scatter(avrg_M17.index,avrg_M17.wind)
plt.title('2017')


plt.subplot(1,3,2)
plt.scatter(avrg_M18.index,avrg_M18.wind)
plt.title('2018')

plt.subplot(1,3,3)
plt.scatter(avrg_M19.index,avrg_M19.wind)
plt.title('2019')
# Out:
# Text(0.5, 1.0, '2019')

# %%
avrg_SW=avrg.loc[(avrg.index),['sunny','wind']]
avrg_SW
# Out:
#             sunny       wind
# region
# Aljawf  37.278892  13.853331
# Assir   26.972123  12.350942
# Baha    27.852097  14.591037
# ER      36.595515  14.850554
# Hail    34.491327  12.876696
# Jazan   26.733572  12.374704
# Madina  37.700977  11.793038
# Mecca   32.188672  13.909883
# NB      40.004942  13.601285
# Najran  26.754673  12.393888
# Qassim  34.628404  12.863967
# Riyadh  30.899458  10.570915
# Tabuk   34.649209  11.951408
